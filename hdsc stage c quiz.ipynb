# %%
import pandas as pd
# !pip install imblearn
import numpy as np
# Out:
# Requirement already satisfied: imblearn in c:\users\tega\anaconda3\lib\site-packages (0.0)
# Requirement already satisfied: imbalanced-learn in c:\users\tega\anaconda3\lib\site-packages (from imblearn) (0.9.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\tega\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.1.0)
# Requirement already satisfied: numpy>=1.14.6 in c:\users\tega\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.20.3)
# Requirement already satisfied: scikit-learn>=1.0.1 in c:\users\tega\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.0.2)
# Requirement already satisfied: scipy>=1.1.0 in c:\users\tega\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.7.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\tega\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (2.2.0)

# %%
df= pd.read_csv("Data_for_UCI_named.csv")
df.head()
# Out:
#        tau1      tau2      tau3      tau4        p1        p2        p3  \
# 0  2.959060  3.079885  8.381025  9.780754  3.763085 -0.782604 -1.257395
# 1  9.304097  4.902524  3.047541  1.369357  5.067812 -1.940058 -1.872742
# 2  8.971707  8.848428  3.046479  1.214518  3.405158 -1.207456 -1.277210
# 3  0.716415  7.669600  4.486641  2.340563  3.963791 -1.027473 -1.938944
# 4  3.134112  7.608772  4.943759  9.857573  3.525811 -1.125531 -1.845975
#
#          p4        g1        g2        g3        g4      stab     stabf
# 0 -1.723086  0.650456  0.859578  0.887445  0.958034  0.055347  unstable
# 1 -1.255012  0.413441  0.862414  0.562139  0.781760 -0.005957    stable
# 2 -0.920492  0.163041  0.766689  0.839444  0.109853  0.003471  unstable
# 3 -0.997374  0.446209  0.976744  0.929381  0.362718  0.028871  unstable
# 4 -0.554305  0.797110  0.455450  0.656947  0.820923  0.049860  unstable

# %%
df.describe(include = 'all')
# Out:
#                 tau1          tau2          tau3          tau4            p1  \
# count   10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean        5.250000      5.250001      5.250004      5.249997      3.750000
# std         2.742548      2.742549      2.742549      2.742556      0.752160
# min         0.500793      0.500141      0.500788      0.500473      1.582590
# 25%         2.874892      2.875140      2.875522      2.874950      3.218300
# 50%         5.250004      5.249981      5.249979      5.249734      3.751025
# 75%         7.624690      7.624893      7.624948      7.624838      4.282420
# max         9.999469      9.999837      9.999450      9.999443      5.864418
#
#                   p2            p3            p4            g1            g2  \
# count   10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean       -1.250000     -1.250000     -1.250000      0.525000      0.525000
# std         0.433035      0.433035      0.433035      0.274256      0.274255
# min        -1.999891     -1.999945     -1.999926      0.050009      0.050053
# 25%        -1.624901     -1.625025     -1.624960      0.287521      0.287552
# 50%        -1.249966     -1.249974     -1.250007      0.525009      0.525003
# 75%        -0.874977     -0.875043     -0.875065      0.762435      0.762490
# max        -0.500108     -0.500072     -0.500025      0.999937      0.999944
#
#                   g3            g4          stab     stabf
# count   10000.000000  10000.000000  10000.000000     10000
# unique           NaN           NaN           NaN         2
# top              NaN           NaN           NaN  unstable
# freq             NaN           NaN           NaN      6380
# mean        0.525000      0.525000      0.015731       NaN
# std         0.274255      0.274255      0.036919       NaN
# min         0.050054      0.050028     -0.080760       NaN
# 25%         0.287514      0.287494     -0.015557       NaN
# 50%         0.525015      0.525002      0.017142       NaN
# 75%         0.762440      0.762433      0.044878       NaN
# max         0.999982      0.999930      0.109403       NaN

# %%
df.isna().sum()
# Out:
# tau1     0
# tau2     0
# tau3     0
# tau4     0
# p1       0
# p2       0
# p3       0
# p4       0
# g1       0
# g2       0
# g3       0
# g4       0
# stab     0
# stabf    0
# dtype: int64

# %%
#dropping the stab column
df = df.drop(columns = 'stab')
df
# Out:
#           tau1      tau2      tau3      tau4        p1        p2        p3  \
# 0     2.959060  3.079885  8.381025  9.780754  3.763085 -0.782604 -1.257395
# 1     9.304097  4.902524  3.047541  1.369357  5.067812 -1.940058 -1.872742
# 2     8.971707  8.848428  3.046479  1.214518  3.405158 -1.207456 -1.277210
# 3     0.716415  7.669600  4.486641  2.340563  3.963791 -1.027473 -1.938944
# 4     3.134112  7.608772  4.943759  9.857573  3.525811 -1.125531 -1.845975
# ...        ...       ...       ...       ...       ...       ...       ...
# 9995  2.930406  9.487627  2.376523  6.187797  3.343416 -0.658054 -1.449106
# 9996  3.392299  1.274827  2.954947  6.894759  4.349512 -1.663661 -0.952437
# 9997  2.364034  2.842030  8.776391  1.008906  4.299976 -1.380719 -0.943884
# 9998  9.631511  3.994398  2.757071  7.821347  2.514755 -0.966330 -0.649915
# 9999  6.530527  6.781790  4.349695  8.673138  3.492807 -1.390285 -1.532193
#
#             p4        g1        g2        g3        g4     stabf
# 0    -1.723086  0.650456  0.859578  0.887445  0.958034  unstable
# 1    -1.255012  0.413441  0.862414  0.562139  0.781760    stable
# 2    -0.920492  0.163041  0.766689  0.839444  0.109853  unstable
# 3    -0.997374  0.446209  0.976744  0.929381  0.362718  unstable
# 4    -0.554305  0.797110  0.455450  0.656947  0.820923  unstable
# ...        ...       ...       ...       ...       ...       ...
# 9995 -1.236256  0.601709  0.779642  0.813512  0.608385  unstable
# 9996 -1.733414  0.502079  0.567242  0.285880  0.366120    stable
# 9997 -1.975373  0.487838  0.986505  0.149286  0.145984    stable
# 9998 -0.898510  0.365246  0.587558  0.889118  0.818391  unstable
# 9999 -0.570329  0.073056  0.505441  0.378761  0.942631  unstable
#
# [10000 rows x 13 columns]

# %%
df['stabf'].value_counts()
# Out:
# unstable    6380
# stable      3620
# Name: stabf, dtype: int64

# %%
x = df.drop(columns = 'stabf')
y = df['stabf']

# %%
#split data into training and testing sets
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y,test_size =0.2, random_state= 1 )
y_train.value_counts()
# Out:
# unstable    5092
# stable      2908
# Name: stabf, dtype: int64

# %%
#Use standard scaler
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)
x_train_scaled = pd.DataFrame(x_train_scaled, columns = x_train.columns)
x_test_scaled = pd.DataFrame(x_test_scaled, columns = x_test.columns)

# %%
#Building the random forest model
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(random_state = 1)

# %%
rf.fit(x_train_scaled, y_train)
#accuracy
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test, rf_pred)
print('Accuracy: {}'.format(round(accuracy*100), 4))
from sklearn.metrics import recall_score, precision_score, f1_score, confusion_matrix, classification_report

#precision
precision = precision_score(y_test, rf_pred, pos_label='stable')
print('Precision: {}'.format(round(precision*100), 2))  

#recall
recall = recall_score(y_test, rf_pred, pos_label='stable')
print('Recall: {}'.format(round(recall*100), 2))

#F1 score
f1 = f1_score(y_test, rf_pred, pos_label='stable')
print('F1: {}'.format(round(f1*100), 2))
# Out:
# Accuracy: 93
# Precision: 92
# Recall: 88
# F1: 90

# %%
# ExtraTreeClassifier
from sklearn.ensemble import ExtraTreesClassifier
etc = ExtraTreesClassifier(random_state = 1)

# %%
etc.fit(x_train_scaled, y_train)
#accuracy
etc_accuracy = accuracy_score(y_test, etc_pred)
print('Accuracy: {}'.format(round(etc_accuracy*100), 2))

#precision
etc_precision = precision_score(y_test, etc_pred, pos_label='stable')
print('Precision: {}'.format(round(etc_precision*100), 2))  

#recall
etc_recall = recall_score(y_test, etc_pred, pos_label='stable')
print('Recall: {}'.format(round(etc_recall*100), 2))

#F1 score
etc_f1 = f1_score(y_test, etc_pred, pos_label='stable')
print('F1: {}'.format(round(etc_f1*100), 2))
# Out:
# Accuracy: 93
# Precision: 94
# Recall: 85
# F1: 89

# %%
etc_pred = etc.predict(x_test_scaled)

# %%
import xgboost
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6300/2457254733.py in <module>
# ----> 1 import xgboost
#
# ModuleNotFoundError: No module named 'xgboost'

# %%
from xgboost import XGBClassifier
xgb= XGBClassifier(random_state = 1)
